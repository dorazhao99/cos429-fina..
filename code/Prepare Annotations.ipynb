# %%
import os
from pycocotools.coco import COCO
import csv, json
import pandas as pd
import cv2

# %%
# copy and rename files
import os
import shutil

def copy_rename(org_dir, new_dir, old_file_name, new_file_name):
    src_dir = ("../images/" + org_dir + "/")
    dst_dir = ("../images/" + new_dir + "/")
    src_file = os.path.join(src_dir, old_file_name)
    shutil.copy(src_file,dst_dir)
    dst_file = os.path.join(dst_dir, old_file_name)
    new_dst_file_name = os.path.join(dst_dir, new_file_name)
    os.rename(dst_file, new_dst_file_name)

# %%
# create an annotation file as a json
def createAnnFile(output, visited, aug):
    df = pd.read_csv('../annotations/otherImgAnnotations.csv') 
    images = df["image"].tolist()
    caption = df["pair_caption"].tolist()
    for i, im in enumerate(images):
        im = im.split('.')[0]
        split_id = im.split("_")
        im_id = str(split_id[3]) + str(split_id[4]) + aug + ".jpg"
        if im_id not in visited:
            output["images"].append({"id": int(im_id.split(".")[0]), "file_name": im_id})
            visited[im_id] = True
        output["annotations"].append({"image_id": int(im_id.split(".")[0]), "caption": caption[i]})
    return visited, output

# %%
instancesFile = '../annotations/instances_val2017.json'
annFile = '../annotations/captions_val2017.json'
cocoInstances = COCO(instancesFile)
cocoAnn = COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=1.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.10s)
# creating index...
# index created!

# %%
# create file called other img annotations
with open('../annotations/otherImgAnnotations.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['image', 'gt_caption'])
    for image in os.listdir('../images/other'):
        img_id = int(image.split('_')[3])
        annIds = cocoAnn.getAnnIds(imgIds = img_id)
        anns = cocoAnn.loadAnns(ids = annIds)
        for ann in anns:
            writer.writerow([image, ann])

# %%
df = pd.read_csv('../annotations/otherImgAnnotations.csv')
images = df["image"].tolist()
caption = df["pair_caption"].tolist()
visited = {}
output = {"annotations":[], "images":[]}
for i, im in enumerate(images):
    im_id = str(im.split("_")[3]) + str(im.split("_")[4])
    if im_id not in visited:
        output["images"].append({"id": int(im_id.split(".")[0]), "file_name": im_id})
        visited[im_id] = True
    output["annotations"].append({"image_id": int(im_id.split(".")[0]), "caption": caption[i]})

# %%
with open('../annotations/augAnn.json', 'w') as f:
    json.dump(output, f)

# %%
for file in os.listdir("../images/other images (resized)/data augmentations/flipped/flipped blocked/"):
    if not file.startswith('.'):
        filename = "../images/other images (resized)/data augmentations/flipped/flipped blocked/" + file
        print(filename)
        new_filename = "../images/other images (resized)/data augmentations/flipped/flipped blocked/" + file
        img = cv2.imread(filename)
        w, h, _ = img.shape

        scale_percent = 400 / w
        height = int(h * scale_percent)
        dsize = (height, 400)
        output = cv2.resize(img, dsize, interpolation = cv2.INTER_AREA)
        cv2.imwrite(new_filename, output)
# Out:
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_handbag_153529_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_hairdrier_384136_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_456662_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_55950_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_150417_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_33759_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_127263_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_88485_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_51314_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_190007_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_150417_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_7278_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_55950_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_456662_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_127263_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_33759_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_190007_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_7278_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_127530_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_72281_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_19432_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_51314_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_hairdrier_384136_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_handbag_153529_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_192670_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_127530_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_190007_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_33759_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_127263_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_51314_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_192670_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_handbag_153529_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_19432_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_72281_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_33759_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_190007_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_127530_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_72281_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_19432_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_51314_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_192670_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_127530_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_55950_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_33759_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_127263_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_51314_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_192670_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_handbag_153529_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_72281_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_19432_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_192670_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_hairdrier_384136_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_72281_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_88485_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_7278_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_456662_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_55950_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_150417_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_88485_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_hairdrier_384136_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_150417_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_7278_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_456662_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_125472_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_324614_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_325991_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_handbag_81594_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_465179_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_128699_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_177357_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_515982_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_445999_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_88970_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_465179_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_22705_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_128699_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_324614_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_125472_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_515982_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_177357_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_157365_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_64718_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_157365_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_177357_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_89296_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_128699_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_22705_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_324614_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_64718_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_22705_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_handbag_81594_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_325991_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_64718_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_88970_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_157365_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_89296_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_22705_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_125472_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_89296_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_157365_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_64718_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_515982_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_22705_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_325991_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_125472_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_324614_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_handbag_81594_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_465179_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_128699_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_177357_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_445999_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_88970_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_465179_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_128699_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_handbag_81594_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_324614_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_445999_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_515982_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_89296_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_135604_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_371552_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_31093_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_187362_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_328238_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_280930_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_4765_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_280930_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_31093_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_187362_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_32570_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_371552_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_85772_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_4765_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_85772_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_hairdrier_350002_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_371552_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_135604_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_507473_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_tie_21604_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_187362_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_328238_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_4765_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_tie_163682_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_85772_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_tie_21604_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_507473_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_31093_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_135604_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_54164_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_85772_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_hairdrier_350002_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_54164_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_507473_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_32570_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_tie_21604_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_racket_85772_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_tie_21604_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_toothbrush_507473_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_135604_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_54164_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_hairdrier_350002_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_54164_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_328238_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_hairdrier_350002_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_280930_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_4765_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_280930_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_328238_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_187362_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_31093_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_371552_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_13201_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_13201_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_tie_131444_6_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_429690_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_115898_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_280918_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_227482_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_tie_131444_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_13201_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_429690_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_115898_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_291619_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_tie_131444_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_227482_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_280918_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_115898_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_429690_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_280918_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_227482_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_tie_131444_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_291619_5_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_surfboard_115898_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_sports_429690_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_291619_4_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_tie_131444_3_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_280918_2_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_m_refrigerator_280918_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_frisbee_227482_1_flipped_blocked.png
# ../images/other images (resized)/data augmentations/flipped/flipped blocked/f_f_skateboard_13201_5_flipped_blocked.png

# %%
visited = {}
output = {"annotations":[], "images":[]}
visited, output = createAnnFile(output, visited, "")
# visited, output = createAnnFile(output, visited, "15")
# visited, output = createAnnFile(output, visited, "25")
# visited, output = createAnnFile(output, visited, "35")
# visited, output = createAnnFile(output, visited, "45")

# %%
with open('../annotations/augAnn_1_blocked.json', 'w') as f:
    json.dump(output, f)

# %%
for im in os.listdir('../images/similar images'):
    if not im.startswith('.'):
        org_dir = 'similar images'
        new_dir = 'sim_blocked_average'
        old_file_name = im
        stripped = im.split('.')[0]
        new_file_name = stripped.split("_")[3] + "6.jpg"
        copy_rename(org_dir, new_dir, old_file_name, new_file_name)
