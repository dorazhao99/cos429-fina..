# %% [markdown]
# # Evaluate Captions
# Adapted from salaniz's Github repo

# %%
from eval_special import COCOEvalCap
from pycocotools.coco import COCO
import matplotlib.pyplot as plt

import json
from json import encoder
encoder.FLOAT_REPR = lambda o: format(o, '.3f')

# %%
# create coco object and cocoRes object
annFile = '/Volumes/G-DRIVE mobile USB-C/cos429-fina../results/gtAnns.json'
resFile = '/Volumes/G-DRIVE mobile USB-C/cos429-fina../results/resblockMaleConf.json'

# %%
coco = COCOEvalCap(annFile, resFile)

# %%
coco.evaluate()
# Out:
# {515982: [{'image_id': 515982, 'caption': 'A man sliding into a base next to another baseball player.'}, {'image_id': 515982, 'caption': 'A baseball player sliding into home plate, in a game.'}, {'image_id': 515982, 'caption': 'a  runner sliding into base as the ball gets close'}, {'image_id': 515982, 'caption': 'a man is sliding up to a base at a baseball game'}, {'image_id': 515982, 'caption': 'A man sliding into home plate as another catches a baseball.'}], 33759: [{'image_id': 33759, 'caption': 'A boy swinging a baseball bat at a game.'}, {'image_id': 33759, 'caption': 'A young boy swinging a baseball bat at a baseball.'}, {'image_id': 33759, 'caption': 'A young baseball player stands at the plate, in motion to hit an oncoming ball. '}, {'image_id': 33759, 'caption': 'a boy swinging his baseball bat at a baseball'}, {'image_id': 33759, 'caption': 'A little kid swinging a bat in a baseball game.'}], 89296: [{'image_id': 89296, 'caption': 'A man holding a baseball bat preparing to 
# ...
