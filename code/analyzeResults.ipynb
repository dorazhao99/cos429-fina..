# %% [markdown]
# # Analyze Results
# Processes the JSON file returned from the model and also runs evaluation code for different image captionign metrics

# %% [markdown]
# ## Process JSON File

# %%
import json
import os

# %%
FILE = 'equalizer'

# %%
filepath = '../results/{0}.json'.format(FILE)

# %%
input_file = open(filepath)
json_array = json.load(input_file)

# %%
os.path.basename(json_array[0]['filename'])
# Out:
# 'f_f_sports_515982_2.jpg'

# %%
parsed_results = []
for img in json_array:
    caption = img['caption']
    file = os.path.basename(img['filename']).split('_')
    file_num = file[3].split('.')[0]
    gender = file[1]
    category = file[2]
    source = os.path.basename(img['filename'])
    if source is 'f':
        source = 'Flickr'
    else:
        source = 'COCO'
    parsed_results.append([caption, file_num, gender, category, source, os.path.basename(img['filename'])])
    print('Caption: {0} Gender: {1} Category: {2} Source: {3}'.format(caption, gender, category, source))
# Out:
# Caption: a baseball player swinging a bat at a ball. Gender: f Category: sports Source: COCO
# Caption: a black and white photo of a person wearing a suit and tie. Gender: f Category: tie Source: COCO
# Caption: a group of young people playing a game of frisbee. Gender: f Category: frisbee Source: COCO
# Caption: a man riding a skateboard up the side of a ramp. Gender: m Category: skateboard Source: COCO
# Caption: a person jumping a skate board in the air. Gender: m Category: skateboard Source: COCO
# Caption: a woman holding a baby in her arms. Gender: f Category: toothbrush Source: COCO
# Caption: a man holding a hot dog in his hands. Gender: m Category: hairdrier Source: COCO
# Caption: a female tennis player in action on the court. Gender: f Category: racket Source: COCO
# Caption: a woman walking down a street while talking on a cell phone. Gender: f Category: skateboard Source: COCO
# Caption: a man brushing his teeth with a tooth brush. Gender: m Category: toothbrush Source: COCO
# Caption: a woman holding a toothbrush in her hand. Gender: f Category: toothbrush Source: COCO
# Caption: a tennis player swinging a racket at a ball. Gender: m Category: racket Source: COCO
# Caption: a man standing on a beach holding a surfboard. Gender: m Category: surfboard Source: COCO
# Caption: a baseball player swinging a bat at a ball. Gender: m Category: sports Source: COCO
# Caption: a female tennis player in action on the court. Gender: f Category: racket Source: COCO
# Caption: a baseball player swinging a bat at a ball. Gender: m Category: sports Source: COCO
# Caption: a female tennis player in action on the court. Gender: f Category: racket Source: COCO
# Caption: a man taking a selfie in a bathroom mirror. Gender: m Category: toothbrush Source: COCO
# Caption: a man is throwing a frisbee in a park. Gender: m Category: frisbee Source: COCO
# Caption: a young man holding a frisbee in a park. Gender: m Category: frisbee Source: COCO
# Caption: a female tennis player in action on the court. Gender: f Category: racket Source: COCO
# Caption: a man riding a wave on top of a surfboard. Gender: m Category: surfboard Source: COCO
# Caption: a man is holding a box of doughnuts. Gender: m Category: refrigerator Source: COCO
# Caption: a woman standing in a room holding a nintendo wii game controller. Gender: f Category: refrigerator Source: COCO
# Caption: a man holding a tennis racquet on a tennis court. Gender: m Category: racket Source: COCO
# Caption: a man riding a skateboard up the side of a ramp. Gender: m Category: skateboard Source: COCO
# Caption: a man in a suit and tie standing in the grass. Gender: m Category: tie Source: COCO
# Caption: a man riding a skateboard up the side of a ramp. Gender: f Category: skateboard Source: COCO
# Caption: a man riding a wave on top of a surfboard. Gender: m Category: surfboard Source: COCO
# Caption: a young girl wearing a tie and smiling. Gender: f Category: tie Source: COCO
# Caption: a soccer player kicking a soccer ball on a field. Gender: f Category: sports Source: COCO
# Caption: a man holding a toothbrush in his hand. Gender: m Category: toothbrush Source: COCO
# Caption: a group of young men playing a game of frisbee. Gender: f Category: frisbee Source: COCO
# Caption: a woman sitting on a couch holding a cell phone. Gender: f Category: hairdrier Source: COCO
# Caption: a man in a suit and tie sitting in a chair. Gender: m Category: tie Source: COCO
# Caption: a female tennis player in action on the court. Gender: f Category: racket Source: COCO
# Caption: a woman standing next to a luggage bag on the ground. Gender: f Category: handbag Source: COCO
# Caption: a man riding a wave on top of a surfboard. Gender: f Category: surfboard Source: COCO
# Caption: a group of young men playing a game of frisbee. Gender: f Category: frisbee Source: COCO
# Caption: a young boy kicking a soccer ball on a field. Gender: m Category: sports Source: COCO
# Caption: a person riding a surf board on a wave. Gender: f Category: surfboard Source: COCO
# Caption: a woman holding a tennis racquet on a tennis court. Gender: f Category: frisbee Source: COCO
# Caption: a man riding a skateboard down a street. Gender: m Category: skateboard Source: COCO
# Caption: a man on a field with a frisbee. Gender: m Category: frisbee Source: COCO
# Caption: a person standing in a kitchen next to a refrigerator. Gender: m Category: refrigerator Source: COCO
# Caption: a man riding a skateboard up the side of a ramp. Gender: m Category: skateboard Source: COCO
# Caption: a man riding a wave on top of a surfboard. Gender: m Category: surfboard Source: COCO
# Caption: a group of young men playing a game of frisbee. Gender: m Category: frisbee Source: COCO
# Caption: a woman standing in a kitchen preparing food. Gender: f Category: refrigerator Source: COCO
# Caption: a person riding a surf board on a wave. Gender: f Category: surfboard Source: COCO
# Caption: a baseball player swinging a bat at a ball. Gender: f Category: sports Source: COCO
# Caption: a male tennis player in action on the court. Gender: m Category: racket Source: COCO
# Caption: a baseball player swinging a bat at a ball. Gender: m Category: sports Source: COCO
# Caption: a tennis player swinging a racket at a ball. Gender: m Category: racket Source: COCO
# Caption: a man in a white shirt is throwing a frisbee. Gender: f Category: frisbee Source: COCO
# Caption: a man riding a wave on top of a surfboard. Gender: m Category: surfboard Source: COCO
# Caption: a person holding an umbrella in the rain. Gender: m Category: handbag Source: COCO
# Caption: a man riding a wave on top of a surfboard. Gender: m Category: surfboard Source: COCO
# Caption: a person on a skateboard does a trick in the air. Gender: f Category: skateboard Source: COCO
# Caption: a woman standing in a kitchen holding a pan. Gender: f Category: refrigerator Source: COCO
# Caption: a woman is playing tennis on a court. Gender: f Category: frisbee Source: COCO
# Caption: a woman brushing her teeth with a tooth brush. Gender: f Category: toothbrush Source: COCO
# Caption: a male tennis player in action on the court. Gender: m Category: racket Source: COCO
# Caption: a young boy swinging a baseball bat at a ball. Gender: f Category: sports Source: COCO
# Caption: a man in a suit and tie is smiling. Gender: m Category: tie Source: COCO
# Caption: a man riding a skateboard up the side of a ramp. Gender: m Category: skateboard Source: COCO
# Caption: a man brushing his teeth with a tooth brush. Gender: m Category: toothbrush Source: COCO
# Caption: a woman is holding a frisbee in a park. Gender: m Category: frisbee Source: COCO
# Caption: a young boy swinging a baseball bat at a ball. Gender: m Category: sports Source: COCO
# Caption: a man riding a wave on top of a surfboard. Gender: m Category: surfboard Source: COCO
# Caption: a man riding a wave on top of a surfboard. Gender: f Category: surfboard Source: COCO
# Caption: a man is holding a glass of wine. Gender: m Category: hairdrier Source: COCO
# Caption: a woman on a surfboard riding a wave. Gender: f Category: surfboard Source: COCO
# Caption: a man riding a wave on top of a surfboard. Gender: f Category: surfboard Source: COCO
# Caption: a young girl wearing a dress shirt and tie. Gender: f Category: tie Source: COCO
# Caption: a person riding a skate board at a skate park. Gender: f Category: skateboard Source: COCO
# Caption: a young boy kicking a soccer ball on a field. Gender: f Category: sports Source: COCO
# Caption: a female tennis player in action on the court. Gender: f Category: racket Source: COCO
# Caption: a man brushing his teeth with a tooth brush. Gender: f Category: toothbrush Source: COCO
# Caption: a woman holding a nintendo wii game controller. Gender: f Category: hairdrier Source: COCO
# Caption: a man riding a wave on top of a surfboard. Gender: m Category: surfboard Source: COCO
# Caption: a soccer player kicking a soccer ball on a field. Gender: m Category: sports Source: COCO
# Caption: a woman standing on a beach holding a surfboard. Gender: f Category: surfboard Source: COCO
# Caption: a baseball player throwing a baseball on a field. Gender: m Category: sports Source: COCO
# Caption: a woman sitting at a table with a cake. Gender: m Category: refrigerator Source: COCO
# Caption: a woman holding an umbrella in the rain. Gender: f Category: handbag Source: COCO
# Caption: a man standing next to a pile of luggage. Gender: m Category: handbag Source: COCO
# Caption: a person riding a surf board on a wave. Gender: m Category: surfboard Source: COCO
# Caption: a woman standing in a kitchen next to a refrigerator. Gender: f Category: refrigerator Source: COCO
# Caption: a male tennis player in action on the court. Gender: m Category: racket Source: COCO
# Caption: a man in a field throwing a frisbee. Gender: m Category: frisbee Source: COCO
# Caption: a man in a suit and tie standing in front of a window. Gender: m Category: tie Source: COCO
# Caption: a man in a suit and tie standing in a room. Gender: f Category: tie Source: COCO
# Caption: a woman sitting at a table with a cake. Gender: f Category: refrigerator Source: COCO

# %%
parsed_results
# Out:
# [['a baseball player swinging a bat at a ball.',
#   '515982',
#   'f',
#   'sports',
#   'COCO',
#   'f_f_sports_515982_2.jpg'],
#  ['a black and white photo of a person wearing a suit and tie.',
#   '21604',
#   'f',
#   'tie',
#   'COCO',
#   'f_f_tie_21604_1.jpg'],
#  ['a group of young people playing a game of frisbee.',
#   '127263',
#   'f',
#   'frisbee',
#   'COCO',
#   'f_f_frisbee_127263_4.jpg'],
#  ['a man riding a skateboard up the side of a ramp.',
#   '13201',
#   'm',
#   'skateboard',
#   'COCO',
#   'm_m_skateboard_13201.jpg'],
#  ['a person jumping a skate board in the air.',
#   '128699',
#   'm',
#   'skateboard',
#   'COCO',
#   'm_m_skateboard_128699.jpg'],
#  ['a woman holding a baby in her arms.',
#   '445999',
#   'f',
#   'toothbrush',
#   'COCO',
#   'm_f_toothbrush_445999.jpg'],
#  ['a man holding a hot dog in his hands.',
#   '350002',
#   'm',
#   'hairdrier',
#   'COCO',
#   'f_m_hairdrier_350002_5.jpg'],
#  ['a female tennis player in action on the court.',
#   '64718',
#   'f',
#   'racket',
#   'COCO',
#   'f_f_racket_64718_1.jpg'],
#  ['a woman walking down a street while talking on a cell phone.',
#   '157365',
#   'f',
#   'skateboard',
#   'COCO',
#   'f_f_skateboard_157365_3.jpg'],
#  ['a man brushing his teeth with a tooth brush.',
#   '445999',
#   'm',
#   'toothbrush',
#   'COCO',
#   'f_m_toothbrush_445999_2.jpg'],
#  ['a woman holding a toothbrush in her hand.',
#   '465179',
#   'f',
#   'toothbrush',
#   'COCO',
#   'm_f_toothbrush_465179.jpg'],
#  ['a tennis player swinging a racket at a ball.',
#   '88970',
#   'm',
#   'racket',
#   'COCO',
#   'm_m_racket_88970.jpg'],
#  ['a man standing on a beach holding a surfboard.',
#   '187362',
#   'm',
#   'surfboard',
#   'COCO',
#   'm_m_surfboard_187362.jpg'],
#  ['a baseball player swinging a bat at a ball.',
#   '89296',
#   'm',
#   'sports',
#   'COCO',
#   'm_m_sports_89296.jpg'],
#  ['a female tennis player in action on the court.',
#   '19432',
#   'f',
#   'racket',
#   'COCO',
#   'f_f_racket_19432_2.jpg'],
#  ['a baseball player swinging a bat at a ball.',
#   '429690',
#   'm',
#   'sports',
#   'COCO',
#   'm_m_sports_429690.jpg'],
#  ['a female tennis player in action on the court.',
#   '88970',
#   'f',
#   'racket',
#   'COCO',
#   'f_f_racket_88970_2.jpg'],
#  ['a man taking a selfie in a bathroom mirror.',
#   '507473',
#   'm',
#   'toothbrush',
#   'COCO',
#   'f_m_toothbrush_507473_1.jpg'],
#  ['a man is throwing a frisbee in a park.',
#   '227482',
#   'm',
#   'frisbee',
#   'COCO',
#   'm_m_frisbee_227482.jpg'],
#  ['a young man holding a frisbee in a park.',
#   '328238',
#   'm',
#   'frisbee',
#   'COCO',
#   'm_m_frisbee_328238.jpg'],
#  ['a female tennis player in action on the court.',
#   '88970',
#   'f',
#   'racket',
#   'COCO',
#   'f_f_racket_88970_5.jpg'],
#  ['a man riding a wave on top of a surfboard.',
#   '4765',
#   'm',
#   'surfboard',
#   'COCO',
#   'm_m_surfboard_4765.jpg'],
#  ['a man is holding a box of doughnuts.',
#   '280930',
#   'm',
#   'refrigerator',
#   'COCO',
#   'f_m_refrigerator_280930_1.jpg'],
#  ['a woman standing in a room holding a nintendo wii game controller.',
#   '456662',
#   'f',
#   'refrigerator',
#   'COCO',
#   'm_f_refrigerator_456662.jpg'],
#  ['a man holding a tennis racquet on a tennis court.',
#   '127530',
#   'm',
#   'racket',
#   'COCO',
#   'm_m_racket_127530.jpg'],
#  ['a man riding a skateboard up the side of a ramp.',
#   '125472',
#   'm',
#   'skateboard',
#   'COCO',
#   'm_m_skateboard_125472.jpg'],
#  ['a man in a suit and tie standing in the grass.',
#   '131444',
#   'm',
#   'tie',
#   'COCO',
#   'm_m_tie_131444.jpg'],
#  ['a man riding a skateboard up the side of a ramp.',
#   '125472',
#   'f',
#   'skateboard',
#   'COCO',
#   'f_f_skateboard_125472_2.jpg'],
#  ['a man riding a wave on top of a surfboard.',
#   '51314',
#   'm',
#   'surfboard',
#   'COCO',
#   'm_m_surfboard_51314.jpg'],
#  ['a young girl wearing a tie and smiling.',
#   '152214',
#   'f',
#   'tie',
#   'COCO',
#   'f_f_tie_152214_1.jpg'],
#  ['a soccer player kicking a soccer ball on a field.',
#   '371552',
#   'f',
#   'sports',
#   'COCO',
#   'f_f_sports_371552_4.jpg'],
#  ['a man holding a toothbrush in his hand.',
#   '465179',
#   'm',
#   'toothbrush',
#   'COCO',
#   'f_m_toothbrush_465179_1.jpg'],
#  ['a group of young men playing a game of frisbee.',
#   '291619',
#   'f',
#   'frisbee',
#   'COCO',
#   'f_f_frisbee_291619_2.jpg'],
#  ['a woman sitting on a couch holding a cell phone.',
#   '350002',
#   'f',
#   'hairdrier',
#   'COCO',
#   'm_f_hairdrier_350002.jpg'],
#  ['a man in a suit and tie sitting in a chair.',
#   '163682',
#   'm',
#   'tie',
#   'COCO',
#   'm_m_tie_163682.jpg'],
#  ['a female tennis player in action on the court.',
#   '55950',
#   'f',
#   'racket',
#   'COCO',
#   'f_f_racket_55950_3.jpg'],
#  ['a woman standing next to a luggage bag on the ground.',
#   '153529',
#   'f',
#   'handbag',
#   'COCO',
#   'm_f_handbag_153529.jpg'],
#  ['a man riding a wave on top of a surfboard.',
#   '7278',
#   'f',
#   'surfboard',
#   'COCO',
#   'f_f_surfboard_7278_3.jpg'],
#  ['a group of young men playing a game of frisbee.',
#   '328238',
#   'f',
#   'frisbee',
#   'COCO',
#   'f_f_frisbee_328238_2.jpg'],
#  ['a young boy kicking a soccer ball on a field.',
#   '135604',
#   'm',
#   'sports',
#   'COCO',
#   'm_m_sports_135604.jpg'],
#  ['a person riding a surf board on a wave.',
#   '32570',
#   'f',
#   'surfboard',
#   'COCO',
#   'f_f_surfboard_32570_4.jpg'],
#  ['a woman holding a tennis racquet on a tennis court.',
#   '88485',
#   'f',
#   'frisbee',
#   'COCO',
#   'f_f_frisbee_88485_2.jpg'],
#  ['a man riding a skateboard down a street.',
#   '157365',
#   'm',
#   'skateboard',
#   'COCO',
#   'm_m_skateboard_157365.jpg'],
#  ['a man on a field with a frisbee.',
#   '291619',
#   'm',
#   'frisbee',
#   'COCO',
#   'm_m_frisbee_291619.jpg'],
#  ['a person standing in a kitchen next to a refrigerator.',
#   '456662',
#   'm',
#   'refrigerator',
#   'COCO',
#   'f_m_refrigerator_456662_1.jpg'],
#  ['a man riding a skateboard up the side of a ramp.',
#   '31093',
#   'm',
#   'skateboard',
#   'COCO',
#   'm_m_skateboard_31093.jpg'],
#  ['a man riding a wave on top of a surfboard.',
#   '177357',
#   'm',
#   'surfboard',
#   'COCO',
#   'm_m_surfboard_177357.jpg'],
#  ['a group of young men playing a game of frisbee.',
#   '127263',
#   'm',
#   'frisbee',
#   'COCO',
#   'm_m_frisbee_127263.jpg'],
#  ['a woman standing in a kitchen preparing food.',
#   '280930',
#   'f',
#   'refrigerator',
#   'COCO',
#   'm_f_refrigerator_280930.jpg'],
#  ['a person riding a surf board on a wave.',
#   '177357',
#   'f',
#   'surfboard',
#   'COCO',
#   'f_f_surfboard_177357_5.jpg'],
#  ['a baseball player swinging a bat at a ball.',
#   '429690',
#   'f',
#   'sports',
#   'COCO',
#   'f_f_sports_429690_1.jpg'],
#  ['a male tennis player in action on the court.',
#   '64718',
#   'm',
#   'racket',
#   'COCO',
#   'm_m_racket_64718.jpg'],
#  ['a baseball player swinging a bat at a ball.',
#   '192670',
#   'm',
#   'sports',
#   'COCO',
#   'm_m_sports_192670.jpg'],
#  ['a tennis player swinging a racket at a ball.',
#   '19432',
#   'm',
#   'racket',
#   'COCO',
#   'm_m_racket_19432.jpg'],
#  ['a man in a white shirt is throwing a frisbee.',
#   '88485',
#   'f',
#   'frisbee',
#   'COCO',
#   'f_f_frisbee_88485_1.jpg'],
#  ['a man riding a wave on top of a surfboard.',
#   '7278',
#   'm',
#   'surfboard',
#   'COCO',
#   'm_m_surfboard_7278.jpg'],
#  ['a person holding an umbrella in the rain.',
#   '81594',
#   'm',
#   'handbag',
#   'COCO',
#   'f_m_handbag_81594_3.jpg'],
#  ['a man riding a wave on top of a surfboard.',
#   '190007',
#   'm',
#   'surfboard',
#   'COCO',
#   'm_m_surfboard_190007.jpg'],
#  ['a person on a skateboard does a trick in the air.',
#   '13201',
#   'f',
#   'skateboard',
#   'COCO',
#   'f_f_skateboard_13201_4.jpg'],
#  ['a woman standing in a kitchen holding a pan.',
#   '280918',
#   'f',
#   'refrigerator',
#   'COCO',
#   'm_f_refrigerator_280918.jpg'],
#  ['a woman is playing tennis on a court.',
#   '227482',
#   'f',
#   'frisbee',
#   'COCO',
#   'f_f_frisbee_227482_3.jpg'],
#  ['a woman brushing her teeth with a tooth brush.',
#   '324614',
#   'f',
#   'toothbrush',
#   'COCO',
#   'm_f_toothbrush_324614.jpg'],
#  ['a male tennis player in action on the court.',
#   '55950',
#   'm',
#   'racket',
#   'COCO',
#   'm_m_racket_55950.jpg'],
#  ['a young boy swinging a baseball bat at a ball.',
#   '89296',
#   'f',
#   'sports',
#   'COCO',
#   'f_f_sports_89296_4.jpg'],
#  ['a man in a suit and tie is smiling.',
#   '21604',
#   'm',
#   'tie',
#   'COCO',
#   'm_m_tie_21604.jpg'],
#  ['a man riding a skateboard up the side of a ramp.',
#   '72281',
#   'm',
#   'skateboard',
#   'COCO',
#   'm_m_skateboard_72281.jpg'],
#  ['a man brushing his teeth with a tooth brush.',
#   '445999',
#   'm',
#   'toothbrush',
#   'COCO',
#   'f_m_toothbrush_445999_1.jpg'],
#  ['a woman is holding a frisbee in a park.',
#   '88485',
#   'm',
#   'frisbee',
#   'COCO',
#   'm_m_frisbee_88485.jpg'],
#  ['a young boy swinging a baseball bat at a ball.',
#   '33759',
#   'm',
#   'sports',
#   'COCO',
#   'm_m_sports_33759.jpg'],
#  ['a man riding a wave on top of a surfboard.',
#   '115898',
#   'm',
#   'surfboard',
#   'COCO',
#   'm_m_surfboard_115898.jpg'],
#  ['a man riding a wave on top of a surfboard.',
#   '32570',
#   'f',
#   'surfboard',
#   'COCO',
#   'f_f_surfboard_32570_3.jpg'],
#  ['a man is holding a glass of wine.',
#   '384136',
#   'm',
#   'hairdrier',
#   'COCO',
#   'f_m_hairdrier_384136_2.jpg'],
#  ['a woman on a surfboard riding a wave.',
#   '115898',
#   'f',
#   'surfboard',
#   'COCO',
#   'f_f_surfboard_115898_1.jpg'],
#  ['a man riding a wave on top of a surfboard.',
#   '32570',
#   'f',
#   'surfboard',
#   'COCO',
#   'f_f_surfboard_32570_2.jpg'],
#  ['a young girl wearing a dress shirt and tie.',
#   '131444',
#   'f',
#   'tie',
#   'COCO',
#   'f_f_tie_131444_1.jpg'],
#  ['a person riding a skate board at a skate park.',
#   '31093',
#   'f',
#   'skateboard',
#   'COCO',
#   'f_f_skateboard_31093_5.jpg'],
#  ['a young boy kicking a soccer ball on a field.',
#   '135604',
#   'f',
#   'sports',
#   'COCO',
#   'f_f_sports_135604_4.jpg'],
#  ['a female tennis player in action on the court.',
#   '127530',
#   'f',
#   'racket',
#   'COCO',
#   'f_f_racket_127530_1.jpg'],
#  ['a man brushing his teeth with a tooth brush.',
#   '507473',
#   'f',
#   'toothbrush',
#   'COCO',
#   'm_f_toothbrush_507473.jpg'],
#  ['a woman holding a nintendo wii game controller.',
#   '384136',
#   'f',
#   'hairdrier',
#   'COCO',
#   'm_f_hairdrier_384136.jpg'],
#  ['a man riding a wave on top of a surfboard.',
#   '32570',
#   'm',
#   'surfboard',
#   'COCO',
#   'm_m_surfboard_32570.jpg'],
#  ['a soccer player kicking a soccer ball on a field.',
#   '371552',
#   'm',
#   'sports',
#   'COCO',
#   'm_m_sports_371552.jpg'],
#  ['a woman standing on a beach holding a surfboard.',
#   '187362',
#   'f',
#   'surfboard',
#   'COCO',
#   'f_f_surfboard_187362_4.jpg'],
#  ['a baseball player throwing a baseball on a field.',
#   '515982',
#   'm',
#   'sports',
#   'COCO',
#   'm_m_sports_515982.jpg'],
#  ['a woman sitting at a table with a cake.',
#   '150417',
#   'm',
#   'refrigerator',
#   'COCO',
#   'f_m_refrigerator_150417_1.jpg'],
#  ['a woman holding an umbrella in the rain.',
#   '81594',
#   'f',
#   'handbag',
#   'COCO',
#   'm_f_handbag_81594.jpg'],
#  ['a man standing next to a pile of luggage.',
#   '153529',
#   'm',
#   'handbag',
#   'COCO',
#   'f_m_handbag_153529_4.jpg'],
#  ['a person riding a surf board on a wave.',
#   '54164',
#   'm',
#   'surfboard',
#   'COCO',
#   'm_m_surfboard_54164.jpg'],
#  ['a woman standing in a kitchen next to a refrigerator.',
#   '22705',
#   'f',
#   'refrigerator',
#   'COCO',
#   'm_f_refrigerator_22705.jpg'],
#  ['a male tennis player in action on the court.',
#   '85772',
#   'm',
#   'racket',
#   'COCO',
#   'm_m_racket_85772.jpg'],
#  ['a man in a field throwing a frisbee.',
#   '325991',
#   'm',
#   'frisbee',
#   'COCO',
#   'm_m_frisbee_325991.jpg'],
#  ['a man in a suit and tie standing in front of a window.',
#   '152214',
#   'm',
#   'tie',
#   'COCO',
#   'm_m_tie_152214.jpg'],
#  ['a man in a suit and tie standing in a room.',
#   '163682',
#   'f',
#   'tie',
#   'COCO',
#   'f_f_tie_163682_1.jpg'],
#  ['a woman sitting at a table with a cake.',
#   '150417',
#   'f',
#   'refrigerator',
#   'COCO',
#   'm_f_refrigerator_150417.jpg']]

# %%
# saves captions to csv
import csv
with open('../results/{0}_2.csv'.format(FILE), 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['Caption', 'Filename', 'Gender', 'Category', 'Source', 'File'])
    for i in parsed_results:
        writer.writerow(i)

# %% [markdown]
# ## Process Captions

# %%
import pandas as pd
import json

# %%
# process result annotations
filepath = '../results/{0}.json'.format(FILE)
input_file = open(filepath)
json_array = json.load(input_file)
json_array
# Out:
# [{'caption': 'a baseball player swinging a bat at a ball.',
#   'filename': './data/mscoco/simimages/f_f_sports_515982_2.jpg',
#   'image_id': 2},
#  {'caption': 'a black and white photo of a person wearing a suit and tie.',
#   'filename': './data/mscoco/simimages/f_f_tie_21604_1.jpg',
#   'image_id': 1},
#  {'caption': 'a group of young people playing a game of frisbee.',
#   'filename': './data/mscoco/simimages/f_f_frisbee_127263_4.jpg',
#   'image_id': 4},
#  {'caption': 'a man riding a skateboard up the side of a ramp.',
#   'filename': './data/mscoco/simimages/m_m_skateboard_13201.jpg',
#   'image_id': 13201},
#  {'caption': 'a person jumping a skate board in the air.',
#   'filename': './data/mscoco/simimages/m_m_skateboard_128699.jpg',
#   'image_id': 128699},
#  {'caption': 'a woman holding a baby in her arms.',
#   'filename': './data/mscoco/simimages/m_f_toothbrush_445999.jpg',
#   'image_id': 445999},
#  {'caption': 'a man holding a hot dog in his hands.',
#   'filename': './data/mscoco/simimages/f_m_hairdrier_350002_5.jpg',
#   'image_id': 5},
#  {'caption': 'a female tennis player in action on the court.',
#   'filename': './data/mscoco/simimages/f_f_racket_64718_1.jpg',
#   'image_id': 1},
#  {'caption': 'a woman walking down a street while talking on a cell phone.',
#   'filename': './data/mscoco/simimages/f_f_skateboard_157365_3.jpg',
#   'image_id': 3},
#  {'caption': 'a man brushing his teeth with a tooth brush.',
#   'filename': './data/mscoco/simimages/f_m_toothbrush_445999_2.jpg',
#   'image_id': 2},
#  {'caption': 'a woman holding a toothbrush in her hand.',
#   'filename': './data/mscoco/simimages/m_f_toothbrush_465179.jpg',
#   'image_id': 465179},
#  {'caption': 'a tennis player swinging a racket at a ball.',
#   'filename': './data/mscoco/simimages/m_m_racket_88970.jpg',
#   'image_id': 88970},
#  {'caption': 'a man standing on a beach holding a surfboard.',
#   'filename': './data/mscoco/simimages/m_m_surfboard_187362.jpg',
#   'image_id': 187362},
#  {'caption': 'a baseball player swinging a bat at a ball.',
#   'filename': './data/mscoco/simimages/m_m_sports_89296.jpg',
#   'image_id': 89296},
#  {'caption': 'a female tennis player in action on the court.',
#   'filename': './data/mscoco/simimages/f_f_racket_19432_2.jpg',
#   'image_id': 2},
#  {'caption': 'a baseball player swinging a bat at a ball.',
#   'filename': './data/mscoco/simimages/m_m_sports_429690.jpg',
#   'image_id': 429690},
#  {'caption': 'a female tennis player in action on the court.',
#   'filename': './data/mscoco/simimages/f_f_racket_88970_2.jpg',
#   'image_id': 2},
#  {'caption': 'a man taking a selfie in a bathroom mirror.',
#   'filename': './data/mscoco/simimages/f_m_toothbrush_507473_1.jpg',
#   'image_id': 1},
#  {'caption': 'a man is throwing a frisbee in a park.',
#   'filename': './data/mscoco/simimages/m_m_frisbee_227482.jpg',
#   'image_id': 227482},
#  {'caption': 'a young man holding a frisbee in a park.',
#   'filename': './data/mscoco/simimages/m_m_frisbee_328238.jpg',
#   'image_id': 328238},
#  {'caption': 'a female tennis player in action on the court.',
#   'filename': './data/mscoco/simimages/f_f_racket_88970_5.jpg',
#   'image_id': 5},
#  {'caption': 'a man riding a wave on top of a surfboard.',
#   'filename': './data/mscoco/simimages/m_m_surfboard_4765.jpg',
#   'image_id': 4765},
#  {'caption': 'a man is holding a box of doughnuts.',
#   'filename': './data/mscoco/simimages/f_m_refrigerator_280930_1.jpg',
#   'image_id': 1},
#  {'caption': 'a woman standing in a room holding a nintendo wii game controller.',
#   'filename': './data/mscoco/simimages/m_f_refrigerator_456662.jpg',
#   'image_id': 456662},
#  {'caption': 'a man holding a tennis racquet on a tennis court.',
#   'filename': './data/mscoco/simimages/m_m_racket_127530.jpg',
#   'image_id': 127530},
#  {'caption': 'a man riding a skateboard up the side of a ramp.',
#   'filename': './data/mscoco/simimages/m_m_skateboard_125472.jpg',
#   'image_id': 125472},
#  {'caption': 'a man in a suit and tie standing in the grass.',
#   'filename': './data/mscoco/simimages/m_m_tie_131444.jpg',
#   'image_id': 131444},
#  {'caption': 'a man riding a skateboard up the side of a ramp.',
#   'filename': './data/mscoco/simimages/f_f_skateboard_125472_2.jpg',
#   'image_id': 2},
#  {'caption': 'a man riding a wave on top of a surfboard.',
#   'filename': './data/mscoco/simimages/m_m_surfboard_51314.jpg',
#   'image_id': 51314},
#  {'caption': 'a young girl wearing a tie and smiling.',
#   'filename': './data/mscoco/simimages/f_f_tie_152214_1.jpg',
#   'image_id': 1},
#  {'caption': 'a soccer player kicking a soccer ball on a field.',
#   'filename': './data/mscoco/simimages/f_f_sports_371552_4.jpg',
#   'image_id': 4},
#  {'caption': 'a man holding a toothbrush in his hand.',
#   'filename': './data/mscoco/simimages/f_m_toothbrush_465179_1.jpg',
#   'image_id': 1},
#  {'caption': 'a group of young men playing a game of frisbee.',
#   'filename': './data/mscoco/simimages/f_f_frisbee_291619_2.jpg',
#   'image_id': 2},
#  {'caption': 'a woman sitting on a couch holding a cell phone.',
#   'filename': './data/mscoco/simimages/m_f_hairdrier_350002.jpg',
#   'image_id': 350002},
#  {'caption': 'a man in a suit and tie sitting in a chair.',
#   'filename': './data/mscoco/simimages/m_m_tie_163682.jpg',
#   'image_id': 163682},
#  {'caption': 'a female tennis player in action on the court.',
#   'filename': './data/mscoco/simimages/f_f_racket_55950_3.jpg',
#   'image_id': 3},
#  {'caption': 'a woman standing next to a luggage bag on the ground.',
#   'filename': './data/mscoco/simimages/m_f_handbag_153529.jpg',
#   'image_id': 153529},
#  {'caption': 'a man riding a wave on top of a surfboard.',
#   'filename': './data/mscoco/simimages/f_f_surfboard_7278_3.jpg',
#   'image_id': 3},
#  {'caption': 'a group of young men playing a game of frisbee.',
#   'filename': './data/mscoco/simimages/f_f_frisbee_328238_2.jpg',
#   'image_id': 2},
#  {'caption': 'a young boy kicking a soccer ball on a field.',
#   'filename': './data/mscoco/simimages/m_m_sports_135604.jpg',
#   'image_id': 135604},
#  {'caption': 'a person riding a surf board on a wave.',
#   'filename': './data/mscoco/simimages/f_f_surfboard_32570_4.jpg',
#   'image_id': 4},
#  {'caption': 'a woman holding a tennis racquet on a tennis court.',
#   'filename': './data/mscoco/simimages/f_f_frisbee_88485_2.jpg',
#   'image_id': 2},
#  {'caption': 'a man riding a skateboard down a street.',
#   'filename': './data/mscoco/simimages/m_m_skateboard_157365.jpg',
#   'image_id': 157365},
#  {'caption': 'a man on a field with a frisbee.',
#   'filename': './data/mscoco/simimages/m_m_frisbee_291619.jpg',
#   'image_id': 291619},
#  {'caption': 'a person standing in a kitchen next to a refrigerator.',
#   'filename': './data/mscoco/simimages/f_m_refrigerator_456662_1.jpg',
#   'image_id': 1},
#  {'caption': 'a man riding a skateboard up the side of a ramp.',
#   'filename': './data/mscoco/simimages/m_m_skateboard_31093.jpg',
#   'image_id': 31093},
#  {'caption': 'a man riding a wave on top of a surfboard.',
#   'filename': './data/mscoco/simimages/m_m_surfboard_177357.jpg',
#   'image_id': 177357},
#  {'caption': 'a group of young men playing a game of frisbee.',
#   'filename': './data/mscoco/simimages/m_m_frisbee_127263.jpg',
#   'image_id': 127263},
#  {'caption': 'a woman standing in a kitchen preparing food.',
#   'filename': './data/mscoco/simimages/m_f_refrigerator_280930.jpg',
#   'image_id': 280930},
#  {'caption': 'a person riding a surf board on a wave.',
#   'filename': './data/mscoco/simimages/f_f_surfboard_177357_5.jpg',
#   'image_id': 5},
#  {'caption': 'a baseball player swinging a bat at a ball.',
#   'filename': './data/mscoco/simimages/f_f_sports_429690_1.jpg',
#   'image_id': 1},
#  {'caption': 'a male tennis player in action on the court.',
#   'filename': './data/mscoco/simimages/m_m_racket_64718.jpg',
#   'image_id': 64718},
#  {'caption': 'a baseball player swinging a bat at a ball.',
#   'filename': './data/mscoco/simimages/m_m_sports_192670.jpg',
#   'image_id': 192670},
#  {'caption': 'a tennis player swinging a racket at a ball.',
#   'filename': './data/mscoco/simimages/m_m_racket_19432.jpg',
#   'image_id': 19432},
#  {'caption': 'a man in a white shirt is throwing a frisbee.',
#   'filename': './data/mscoco/simimages/f_f_frisbee_88485_1.jpg',
#   'image_id': 1},
#  {'caption': 'a man riding a wave on top of a surfboard.',
#   'filename': './data/mscoco/simimages/m_m_surfboard_7278.jpg',
#   'image_id': 7278},
#  {'caption': 'a person holding an umbrella in the rain.',
#   'filename': './data/mscoco/simimages/f_m_handbag_81594_3.jpg',
#   'image_id': 3},
#  {'caption': 'a man riding a wave on top of a surfboard.',
#   'filename': './data/mscoco/simimages/m_m_surfboard_190007.jpg',
#   'image_id': 190007},
#  {'caption': 'a person on a skateboard does a trick in the air.',
#   'filename': './data/mscoco/simimages/f_f_skateboard_13201_4.jpg',
#   'image_id': 4},
#  {'caption': 'a woman standing in a kitchen holding a pan.',
#   'filename': './data/mscoco/simimages/m_f_refrigerator_280918.jpg',
#   'image_id': 280918},
#  {'caption': 'a woman is playing tennis on a court.',
#   'filename': './data/mscoco/simimages/f_f_frisbee_227482_3.jpg',
#   'image_id': 3},
#  {'caption': 'a woman brushing her teeth with a tooth brush.',
#   'filename': './data/mscoco/simimages/m_f_toothbrush_324614.jpg',
#   'image_id': 324614},
#  {'caption': 'a male tennis player in action on the court.',
#   'filename': './data/mscoco/simimages/m_m_racket_55950.jpg',
#   'image_id': 55950},
#  {'caption': 'a young boy swinging a baseball bat at a ball.',
#   'filename': './data/mscoco/simimages/f_f_sports_89296_4.jpg',
#   'image_id': 4},
#  {'caption': 'a man in a suit and tie is smiling.',
#   'filename': './data/mscoco/simimages/m_m_tie_21604.jpg',
#   'image_id': 21604},
#  {'caption': 'a man riding a skateboard up the side of a ramp.',
#   'filename': './data/mscoco/simimages/m_m_skateboard_72281.jpg',
#   'image_id': 72281},
#  {'caption': 'a man brushing his teeth with a tooth brush.',
#   'filename': './data/mscoco/simimages/f_m_toothbrush_445999_1.jpg',
#   'image_id': 1},
#  {'caption': 'a woman is holding a frisbee in a park.',
#   'filename': './data/mscoco/simimages/m_m_frisbee_88485.jpg',
#   'image_id': 88485},
#  {'caption': 'a young boy swinging a baseball bat at a ball.',
#   'filename': './data/mscoco/simimages/m_m_sports_33759.jpg',
#   'image_id': 33759},
#  {'caption': 'a man riding a wave on top of a surfboard.',
#   'filename': './data/mscoco/simimages/m_m_surfboard_115898.jpg',
#   'image_id': 115898},
#  {'caption': 'a man riding a wave on top of a surfboard.',
#   'filename': './data/mscoco/simimages/f_f_surfboard_32570_3.jpg',
#   'image_id': 3},
#  {'caption': 'a man is holding a glass of wine.',
#   'filename': './data/mscoco/simimages/f_m_hairdrier_384136_2.jpg',
#   'image_id': 2},
#  {'caption': 'a woman on a surfboard riding a wave.',
#   'filename': './data/mscoco/simimages/f_f_surfboard_115898_1.jpg',
#   'image_id': 1},
#  {'caption': 'a man riding a wave on top of a surfboard.',
#   'filename': './data/mscoco/simimages/f_f_surfboard_32570_2.jpg',
#   'image_id': 2},
#  {'caption': 'a young girl wearing a dress shirt and tie.',
#   'filename': './data/mscoco/simimages/f_f_tie_131444_1.jpg',
#   'image_id': 1},
#  {'caption': 'a person riding a skate board at a skate park.',
#   'filename': './data/mscoco/simimages/f_f_skateboard_31093_5.jpg',
#   'image_id': 5},
#  {'caption': 'a young boy kicking a soccer ball on a field.',
#   'filename': './data/mscoco/simimages/f_f_sports_135604_4.jpg',
#   'image_id': 4},
#  {'caption': 'a female tennis player in action on the court.',
#   'filename': './data/mscoco/simimages/f_f_racket_127530_1.jpg',
#   'image_id': 1},
#  {'caption': 'a man brushing his teeth with a tooth brush.',
#   'filename': './data/mscoco/simimages/m_f_toothbrush_507473.jpg',
#   'image_id': 507473},
#  {'caption': 'a woman holding a nintendo wii game controller.',
#   'filename': './data/mscoco/simimages/m_f_hairdrier_384136.jpg',
#   'image_id': 384136},
#  {'caption': 'a man riding a wave on top of a surfboard.',
#   'filename': './data/mscoco/simimages/m_m_surfboard_32570.jpg',
#   'image_id': 32570},
#  {'caption': 'a soccer player kicking a soccer ball on a field.',
#   'filename': './data/mscoco/simimages/m_m_sports_371552.jpg',
#   'image_id': 371552},
#  {'caption': 'a woman standing on a beach holding a surfboard.',
#   'filename': './data/mscoco/simimages/f_f_surfboard_187362_4.jpg',
#   'image_id': 4},
#  {'caption': 'a baseball player throwing a baseball on a field.',
#   'filename': './data/mscoco/simimages/m_m_sports_515982.jpg',
#   'image_id': 515982},
#  {'caption': 'a woman sitting at a table with a cake.',
#   'filename': './data/mscoco/simimages/f_m_refrigerator_150417_1.jpg',
#   'image_id': 1},
#  {'caption': 'a woman holding an umbrella in the rain.',
#   'filename': './data/mscoco/simimages/m_f_handbag_81594.jpg',
#   'image_id': 81594},
#  {'caption': 'a man standing next to a pile of luggage.',
#   'filename': './data/mscoco/simimages/f_m_handbag_153529_4.jpg',
#   'image_id': 4},
#  {'caption': 'a person riding a surf board on a wave.',
#   'filename': './data/mscoco/simimages/m_m_surfboard_54164.jpg',
#   'image_id': 54164},
#  {'caption': 'a woman standing in a kitchen next to a refrigerator.',
#   'filename': './data/mscoco/simimages/m_f_refrigerator_22705.jpg',
#   'image_id': 22705},
#  {'caption': 'a male tennis player in action on the court.',
#   'filename': './data/mscoco/simimages/m_m_racket_85772.jpg',
#   'image_id': 85772},
#  {'caption': 'a man in a field throwing a frisbee.',
#   'filename': './data/mscoco/simimages/m_m_frisbee_325991.jpg',
#   'image_id': 325991},
#  {'caption': 'a man in a suit and tie standing in front of a window.',
#   'filename': './data/mscoco/simimages/m_m_tie_152214.jpg',
#   'image_id': 152214},
#  {'caption': 'a man in a suit and tie standing in a room.',
#   'filename': './data/mscoco/simimages/f_f_tie_163682_1.jpg',
#   'image_id': 1},
#  {'caption': 'a woman sitting at a table with a cake.',
#   'filename': './data/mscoco/simimages/m_f_refrigerator_150417.jpg',
#   'image_id': 150417}]

# %% [markdown]
# ## Women Also Snowboard Metrics

# %%
def snowboard_metrics(df, filename):
    gender_ratio = len(df[df['Gender_Predict'] == 'f']) / len(df[df['Gender_Predict'] == 'm'])
    error_rate = len(df[df['Gender_Correct'] == 0]) / len(df['Gender_Correct'])
    print('Model Name: {2} | Gender Ratio: {0} | Error Rate: {1}'.format(gender_ratio, error_rate, filename))

# %%
results = []
for file in os.listdir("../results"):
    if file.endswith(".csv"):
        results.append(os.path.join("../results", file))

# %%
for result in results:
    df = pd.read_csv(result)
    snowboard_metrics(df, result)
# Out:
# Model Name: ../results/upweight.csv | Gender Ratio: 0.453125 | Error Rate: 0.22340425531914893
# Model Name: ../results/equalizer.csv | Gender Ratio: 0.574468085106383 | Error Rate: 0.11702127659574468
# Model Name: ../results/confidence.csv | Gender Ratio: 0.4482758620689655 | Error Rate: 0.2127659574468085
# Model Name: ../results/baseline_ft.csv | Gender Ratio: 0.4032258064516129 | Error Rate: 0.2978723404255319
# Model Name: ../results/balanced.csv | Gender Ratio: 0.390625 | Error Rate: 0.2553191489361702

# %%
gender_ratio = len(df[df['Gender'] == 'f']) / len(df[df['Gender'] == 'm'])
print(gender_ratio)
# Out:
# 0.9183673469387755

# %% [markdown]
# ## Format Captions

# %%
import pandas as pd
import json
import os

# %%
FILE = 'equalizer'

# %%
filepath = '../annotations/similarMatch.json'
input_file = open(filepath)
json_array = json.load(input_file)
json_array
# Out:
# {'f_f_frisbee_328238_2.jpg': ['m_m_frisbee_227482.jpg'],
#  'f_f_frisbee_88485_2.jpg': ['m_m_frisbee_88485.jpg'],
#  'f_f_tie_131444_1.jpg': ['m_m_tie_152214.jpg'],
#  'f_f_surfboard_115898_1.jpg': ['m_m_surfboard_115898.jpg'],
#  'f_f_frisbee_227482_3.jpg': ['m_m_frisbee_328238.jpg'],
#  'f_f_sports_371552_4.jpg': ['m_m_sports_135604.jpg'],
#  'f_f_racket_88970_2.jpg': ['m_m_racket_88970.jpg'],
#  'f_f_tie_21604_1.jpg': ['m_m_tie_21604.jpg'],
#  'f_f_surfboard_7278_3.jpg': ['m_m_surfboard_32570.jpg'],
#  'f_f_skateboard_13201_4.jpg': ['m_m_skateboard_13201.jpg',
#   'm_m_skateboard_125472.jpg',
#   'm_m_skateboard_72281.jpg'],
#  'f_f_sports_429690_1.jpg': ['m_m_sports_429690.jpg',
#   'm_m_sports_89296.jpg',
#   'm_m_sports_192670.jpg'],
#  'f_f_frisbee_127263_4.jpg': ['m_m_frisbee_127263.jpg'],
#  'f_f_frisbee_291619_2.jpg': ['m_m_frisbee_291619.jpg'],
#  'f_f_racket_88970_5.jpg': ['m_m_racket_85772.jpg'],
#  'f_f_racket_64718_1.jpg': ['m_m_racket_127530.jpg'],
#  'f_f_surfboard_32570_2.jpg': ['m_m_surfboard_190007.jpg',
#   'm_m_surfboard_177357.jpg'],
#  'f_f_sports_89296_4.jpg': ['m_m_sports_33759.jpg'],
#  'f_f_surfboard_32570_4.jpg': ['m_m_surfboard_51314.jpg',
#   'm_m_surfboard_54164.jpg'],
#  'f_f_tie_163682_1.jpg': ['m_m_tie_163682.jpg'],
#  'f_f_skateboard_157365_3.jpg': ['m_m_skateboard_157365.jpg'],
#  'f_f_sports_515982_2.jpg': ['m_m_sports_515982.jpg'],
#  'f_f_racket_19432_2.jpg': ['m_m_racket_19432.jpg'],
#  'f_f_tie_152214_1.jpg': ['m_m_tie_131444.jpg'],
#  'f_f_skateboard_31093_5.jpg': ['m_m_skateboard_31093.jpg'],
#  'f_f_racket_55950_3.jpg': ['m_m_racket_55950.jpg'],
#  'f_f_frisbee_88485_1.jpg': ['m_m_frisbee_325991.jpg'],
#  'f_f_surfboard_187362_4.jpg': ['m_m_surfboard_187362.jpg'],
#  'f_f_racket_127530_1.jpg': ['m_m_racket_64718.jpg'],
#  'f_f_surfboard_177357_5.jpg': ['m_m_surfboard_7278.jpg'],
#  'f_f_surfboard_32570_3.jpg': ['m_m_surfboard_4765.jpg'],
#  'f_f_skateboard_125472_2.jpg': ['m_m_skateboard_128699.jpg'],
#  'f_f_sports_135604_4.jpg': ['m_m_sports_371552.jpg'],
#  'f_m_handbag_81594_3.jpg': ['m_f_handbag_81594.jpg'],
#  'f_m_toothbrush_445999_2.jpg': ['m_f_toothbrush_445999.jpg'],
#  'f_m_refrigerator_456662_1.jpg': ['m_f_refrigerator_22705.jpg',
#   'm_f_refrigerator_456662.jpg'],
#  'f_m_refrigerator_280930_1.jpg': ['m_f_refrigerator_280930.jpg',
#   'm_f_refrigerator_280918.jpg'],
#  'f_m_toothbrush_465179_1.jpg': ['m_f_toothbrush_465179.jpg'],
#  'f_m_refrigerator_150417_1.jpg': ['m_f_refrigerator_150417.jpg'],
#  'f_m_toothbrush_445999_1.jpg': ['m_f_toothbrush_324614.jpg'],
#  'f_m_handbag_153529_4.jpg': ['m_f_handbag_153529.jpg'],
#  'f_m_hairdrier_384136_2.jpg': ['m_f_hairdrier_384136.jpg'],
#  'f_m_hairdrier_350002_5.jpg': ['m_f_hairdrier_350002.jpg'],
#  'f_m_toothbrush_507473_1.jpg': ['m_f_toothbrush_507473.jpg']}

# %%
df = pd.read_csv('../results/{0}.csv'.format(FILE))
files = df['File'].tolist()
captions = df['Caption'].tolist()

# %%
def formatResults(filename, save):
    df = pd.read_csv(filename)
    files = df['File'].tolist()
    captions = df['Caption'].tolist()
    result = []
    for index, file in enumerate(files):
        split = file.split('_')
        if split[0] is 'm':
            result.append({'image_id': split[3].split('.')[0], "caption": captions[index]})
        else:
            matches = json_array[file]
            for match in matches:
                match_split = match.split('_')
                result.append(({'image_id': match_split[3].split('.')[0] + "6", "caption": captions[index]}))
    with open('../results/res{0}.json'.format(save), 'w') as f:
        json.dump(result, f)

# %%
results = []
for file in os.listdir("../results"):
    if file.endswith(".csv"):
        save = file.split('.')[0]
        formatResults(os.path.join("../results", file), save)

# %%
df = pd.read_csv("../annotations/gtValidation.csv")
df.head()
image_id_f = [int(str(m) + '6') for m in df['image_id_m'].tolist()]
df['image_id_f'] = image_id_f
df.to_csv("../annotations/gtValidation.csv", index=False)

# %%
gt = {}
male_ids = df['image_id_m'].tolist()
coco_caption = df['coco_caption'].tolist()
for index, m in enumerate(male_ids):
    if m not in gt:
        gt[m] = [{'image_id': m, 'caption': coco_caption[index]}]
    else:
        gt[m].append({'image_id': m, 'caption': coco_caption[index]})

# %%
female_ids = df['image_id_f'].tolist()
f_caption = df['sim_caption'].tolist()
for index, m in enumerate(female_ids):
    if m not in gt:
        gt[m] = [{'image_id': m, 'caption': f_caption[index]}]
    else:
        gt[m].append({'image_id': m, 'caption': f_caption[index]})

# %%
with open('../results/gtAnns.json', 'w') as f:
    json.dump(gt, f)
